# %%
# %matplotlib widget

# %%
import numpy as np
import emg3d 
import empymod as ep
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import time
import sys
sys.path.insert(1, 'src')
import pickle 

from Plot import grid

# %% [markdown]
# ## Upload data and sort

# %%
#OUT = np.load('data/data3D_slope10_40pos.pkl', allow_pickle=True)
OUT = np.load('data/data_s1_c1_uc.pkl', allow_pickle=True)

# %%
OUT_sorted = OUT.sort_values(by='geom')

# %%
OUT_sorted
# Out:
#   geom  src_x  rec_x  midpx        op        ip
# 0   H2   -4.0   -2.0  -3.00  0.008163  0.000620
# 0   H2   -3.0   -1.0  -2.00  0.008164  0.000619
# 1   H4   -4.0    0.0  -2.00  0.021786  0.003973
# 1   H4   -3.0    1.0  -1.00  0.021806  0.003975
# 2   H8   -4.0    4.0   0.00  0.039107  0.020318
# 2   H8   -3.0    5.0   1.00  0.039362  0.020356
# 6   P2   -3.0   -0.9  -1.95  0.008394  0.000161
# 6   P2   -4.0   -1.9  -2.95  0.008395  0.000160
# 7   P4   -4.0    0.1  -1.95  0.047954  0.002215
# 7   P4   -3.0    1.1  -0.95  0.047945  0.002219
# 8   P8   -4.0    4.1   0.05  0.121830  0.013667
# 8   P8   -3.0    5.1   1.05  0.122008  0.013735
# 3   V2   -3.0   -1.0  -2.00  0.009937  0.000379
# 3   V2   -4.0   -2.0  -3.00  0.009936  0.000379
# 4   V4   -4.0    0.0  -2.00  0.034350  0.002526
# 4   V4   -3.0    1.0  -1.00  0.034358  0.002529
# 5   V8   -3.0    5.0   1.00  0.099386  0.014751
# 5   V8   -4.0    4.0   0.00  0.099285  0.014729

# %%
npos = int(len(OUT_sorted)/9)

# %%
npos
# Out:
# 2

# %%
data_3D = np.zeros((npos-3,18))

pos=0
for p in range(-3,npos):
    print(OUT_sorted.loc[(OUT_sorted.midpx > p+.06) & (OUT_sorted.midpx <p +1.06)])

    dat = np.hstack((OUT_sorted.loc[(OUT_sorted.midpx > p+.06) & (OUT_sorted.midpx <=p +1.06)]['op'],
                     OUT_sorted.loc[(OUT_sorted.midpx > p+.06) & (OUT_sorted.midpx <=p +1.06)]['ip'])) 
    if dat.size == 0:
        continue
    if dat.size == 18:
        data_3D[pos,:] = dat
        #print('pos:', pos)
        pos += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 data_3D = np.zeros((npos-3,18))
#       3 pos=0
#       4 for p in range(-3,npos):
#
# ValueError: negative dimensions are not allowed

# %%
np.save('data/data_3D_slope10_40pos_sorted', data_3D[1:41])

# %%
np.shape(data_3D[1:41])
# Out:
# (40, 18)
