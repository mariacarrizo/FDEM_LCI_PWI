# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../src')

from showStitched import showStitchedModels

# %%
# load models

m_s1_c1_uc = np.load('models/model_s1_c1_uc.npy')
m_s1_c2_uc = np.load('models/model_s1_c2_uc.npy')
m_s1_c3_uc = np.load('models/model_s1_c3_uc.npy')
m_s1_c4_uc = np.load('models/model_s1_c4_uc.npy')

m_s2_c1_uc = np.load('models/model_s2_c1_uc.npy')
m_s2_c2_uc = np.load('models/model_s2_c2_uc.npy')
m_s2_c3_uc = np.load('models/model_s2_c3_uc.npy')
m_s2_c4_uc = np.load('models/model_s2_c4_uc.npy')

m_s5_c1_uc = np.load('models/model_s3_c1_uc.npy')
m_s5_c2_uc = np.load('models/model_s3_c2_uc.npy')
m_s5_c3_uc = np.load('models/model_s3_c3_uc.npy')
m_s5_c4_uc = np.load('models/model_s3_c4_uc.npy')

m_s10_c1_uc = np.load('models/model_s4_c1_uc.npy')
m_s10_c2_uc = np.load('models/model_s4_c2_uc.npy')
m_s10_c3_uc = np.load('models/model_s4_c3_uc.npy')
m_s10_c4_uc = np.load('models/model_s4_c4_uc.npy')

m_s1_c1_ur = np.load('models/model_s1_c1_ur.npy')
m_s1_c2_ur = np.load('models/model_s1_c2_ur.npy')
m_s1_c3_ur = np.load('models/model_s1_c3_ur.npy')
m_s1_c4_ur = np.load('models/model_s1_c4_ur.npy')

m_s2_c1_ur = np.load('models/model_s2_c1_ur.npy')
m_s2_c2_ur = np.load('models/model_s2_c2_ur.npy')
m_s2_c3_ur = np.load('models/model_s2_c3_ur.npy')
m_s2_c4_ur = np.load('models/model_s2_c4_ur.npy')

m_s5_c1_ur = np.load('models/model_s3_c1_ur.npy')
m_s5_c2_ur = np.load('models/model_s3_c2_ur.npy')
m_s5_c3_ur = np.load('models/model_s3_c3_ur.npy')
m_s5_c4_ur = np.load('models/model_s3_c4_ur.npy')

m_s10_c1_ur = np.load('models/model_s4_c1_ur.npy')
m_s10_c2_ur = np.load('models/model_s4_c2_ur.npy')
m_s10_c3_ur = np.load('models/model_s4_c3_ur.npy')
m_s10_c4_ur = np.load('models/model_s4_c4_ur.npy')

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

showStitchedModels(m_s1_c1_uc, ax=ax[0,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c2_uc, ax=ax[0,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c3_uc, ax=ax[0,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c4_uc, ax=ax[0,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s2_c1_uc, ax=ax[1,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c2_uc, ax=ax[1,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c3_uc, ax=ax[1,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c4_uc, ax=ax[1,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s5_c1_uc, ax=ax[2,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c2_uc, ax=ax[2,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c3_uc, ax=ax[2,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c4_uc, ax=ax[2,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s10_c1_uc, ax=ax[3,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c2_uc, ax=ax[3,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c3_uc, ax=ax[3,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c4_uc, ax=ax[3,3], zMax=7, cMin=20/1000, cMax=2)
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

showStitchedModels(m_s1_c1_ur, ax=ax[0,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c2_ur, ax=ax[0,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c3_ur, ax=ax[0,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s1_c4_ur, ax=ax[0,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s2_c1_ur, ax=ax[1,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c2_ur, ax=ax[1,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c3_ur, ax=ax[1,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s2_c4_ur, ax=ax[1,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s5_c1_ur, ax=ax[2,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c2_ur, ax=ax[2,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c3_ur, ax=ax[2,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s5_c4_ur, ax=ax[2,3], zMax=7, cMin=20/1000, cMax=2)

showStitchedModels(m_s10_c1_ur, ax=ax[3,0], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c2_ur, ax=ax[3,1], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c3_ur, ax=ax[3,2], zMax=7, cMin=20/1000, cMax=2)
showStitchedModels(m_s10_c4_ur, ax=ax[3,3], zMax=7, cMin=20/1000, cMax=2)
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
