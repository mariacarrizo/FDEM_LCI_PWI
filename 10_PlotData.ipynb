# %%
# %matplotlib widget

# %% [markdown]
# # Data difference

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, 'src')

from Plot import Plot2Datas

# %%
# Load 3D data

norm = np.array([8, 4, 1, 8, 4, 1, 8, 4, 1, 8, 4, 1, 8, 4, 1, 8, 4, 1])

# Slope 1 %
data_s1_c1_uc = np.load('data/data_s1_c1_uc_sort.npy')[:40]*norm
data_s1_c2_uc = np.load('data/data_s1_c2_uc_sort.npy')[:40]*norm
data_s1_c3_uc = np.load('data/data_s1_c3_uc_sort.npy')[:40]*norm
data_s1_c4_uc = np.load('data/data_s1_c4_uc_sort.npy')[:40]*norm

# Slope 2 %
data_s2_c1_uc = np.load('data/data_s2_c1_uc_sort.npy')[:40]*norm
data_s2_c2_uc = np.load('data/data_s2_c2_uc_sort.npy')[:40]*norm
data_s2_c3_uc = np.load('data/data_s2_c3_uc_sort.npy')[:40]*norm
data_s2_c4_uc = np.load('data/data_s2_c4_uc_sort.npy')[:40]*norm

# Slope 5 %
data_s3_c1_uc = np.load('data/data_s3_c1_uc_sort.npy')[:40]*norm
data_s3_c2_uc = np.load('data/data_s3_c2_uc_sort.npy')[:40]*norm
data_s3_c3_uc = np.load('data/data_s3_c3_uc_sort.npy')[:40]*norm
data_s3_c4_uc = np.load('data/data_s3_c4_uc_sort.npy')[:40]*norm

# Slope 10 %
data_s4_c1_uc = np.load('data/data_s4_c1_uc_sort.npy')[:40]*norm
data_s4_c2_uc = np.load('data/data_s4_c2_uc_sort.npy')[:40]*norm
data_s4_c3_uc = np.load('data/data_s4_c3_uc_sort.npy')[:40]*norm
data_s4_c4_uc = np.load('data/data_s4_c4_uc_sort.npy')[:40]*norm

# Slope 1 %
data_s1_c1_ur = np.load('data/data_s1_c1_ur_sort.npy')[:40]*norm
data_s1_c2_ur = np.load('data/data_s1_c2_ur_sort.npy')[:40]*norm
data_s1_c3_ur = np.load('data/data_s1_c3_ur_sort.npy')[:40]*norm
data_s1_c4_ur = np.load('data/data_s1_c4_ur_sort.npy')[:40]*norm

# Slope 2 %
data_s2_c1_ur = np.load('data/data_s2_c1_ur_sort.npy')[:40]*norm
data_s2_c2_ur = np.load('data/data_s2_c2_ur_sort.npy')[:40]*norm
data_s2_c3_ur = np.load('data/data_s2_c3_ur_sort.npy')[:40]*norm
data_s2_c4_ur = np.load('data/data_s2_c4_ur_sort.npy')[:40]*norm

# Slope 5 %
data_s3_c1_ur = np.load('data/data_s3_c1_ur_sort.npy')[:40]*norm
data_s3_c2_ur = np.load('data/data_s3_c2_ur_sort.npy')[:40]*norm
data_s3_c3_ur = np.load('data/data_s3_c3_ur_sort.npy')[:40]*norm
data_s3_c4_ur = np.load('data/data_s3_c4_ur_sort.npy')[:40]*norm

# Slope 10 %
data_s4_c1_ur = np.load('data/data_s4_c1_ur_sort.npy')[:40]*norm
data_s4_c2_ur = np.load('data/data_s4_c2_ur_sort.npy')[:40]*norm
data_s4_c3_ur = np.load('data/data_s4_c3_ur_sort.npy')[:40]*norm
data_s4_c4_ur = np.load('data/data_s4_c4_ur_sort.npy')[:40]*norm

# Load 1D data

# Slope 1 %
data_s1_c1_uc_1D = np.load('data/data_s1_c1_uc_1D.npy')
data_s1_c2_uc_1D = np.load('data/data_s1_c2_uc_1D.npy')
data_s1_c3_uc_1D = np.load('data/data_s1_c3_uc_1D.npy')
data_s1_c4_uc_1D = np.load('data/data_s1_c4_uc_1D.npy')

# Slope 2 %
data_s2_c1_uc_1D = np.load('data/data_s2_c1_uc_1D.npy')
data_s2_c2_uc_1D = np.load('data/data_s2_c2_uc_1D.npy')
data_s2_c3_uc_1D = np.load('data/data_s2_c3_uc_1D.npy')
data_s2_c4_uc_1D = np.load('data/data_s2_c4_uc_1D.npy')

# Slope 5 %
data_s3_c1_uc_1D = np.load('data/data_s3_c1_uc_1D.npy')
data_s3_c2_uc_1D = np.load('data/data_s3_c2_uc_1D.npy')
data_s3_c3_uc_1D = np.load('data/data_s3_c3_uc_1D.npy')
data_s3_c4_uc_1D = np.load('data/data_s3_c4_uc_1D.npy')

# Slope 10 %
data_s4_c1_uc_1D = np.load('data/data_s4_c1_uc_1D.npy')
data_s4_c2_uc_1D = np.load('data/data_s4_c2_uc_1D.npy')
data_s4_c3_uc_1D = np.load('data/data_s4_c3_uc_1D.npy')
data_s4_c4_uc_1D = np.load('data/data_s4_c4_uc_1D.npy')

# Slope 1 %
data_s1_c1_ur_1D = np.load('data/data_s1_c1_ur_1D.npy')
data_s1_c2_ur_1D = np.load('data/data_s1_c2_ur_1D.npy')
data_s1_c3_ur_1D = np.load('data/data_s1_c3_ur_1D.npy')
data_s1_c4_ur_1D = np.load('data/data_s1_c4_ur_1D.npy')

# Slope 2 %
data_s2_c1_ur_1D = np.load('data/data_s2_c1_ur_1D.npy')
data_s2_c2_ur_1D = np.load('data/data_s2_c2_ur_1D.npy')
data_s2_c3_ur_1D = np.load('data/data_s2_c3_ur_1D.npy')
data_s2_c4_ur_1D = np.load('data/data_s2_c4_ur_1D.npy')

# Slope 5 %
data_s3_c1_ur_1D = np.load('data/data_s3_c1_ur_1D.npy')
data_s3_c2_ur_1D = np.load('data/data_s3_c2_ur_1D.npy')
data_s3_c3_ur_1D = np.load('data/data_s3_c3_ur_1D.npy')
data_s3_c4_ur_1D = np.load('data/data_s3_c4_ur_1D.npy')

# Slope 10 %
data_s4_c1_ur_1D = np.load('data/data_s4_c1_ur_1D.npy')
data_s4_c2_ur_1D = np.load('data/data_s4_c2_ur_1D.npy')
data_s4_c3_ur_1D = np.load('data/data_s4_c3_ur_1D.npy')
data_s4_c4_ur_1D = np.load('data/data_s4_c4_ur_1D.npy')

# %%
Plot2Datas(data_s1_c1_uc, data_s1_c1_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c2_uc, data_s1_c2_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c3_uc, data_s1_c3_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c4_uc, data_s1_c4_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c1_uc, data_s2_c1_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c2_uc, data_s2_c2_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c3_uc, data_s2_c3_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c4_uc, data_s2_c4_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c1_uc, data_s3_c1_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c2_uc, data_s3_c2_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c4_uc, data_s3_c4_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c4_uc, data_s3_c4_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c1_uc, data_s4_c1_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c2_uc, data_s4_c2_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c3_uc, data_s4_c3_uc_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c1_ur, data_s1_c1_ur_1D)
# Out:
# /home/mariacarrizo/repos/LCI-EMI/src/Plot.py:104: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(3,4, figsize=(10,5), sharex=True)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c2_ur, data_s1_c2_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c3_ur, data_s1_c3_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s1_c4_ur, data_s1_c4_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c1_ur, data_s2_c1_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c2_ur, data_s2_c2_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c3_ur, data_s2_c3_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s2_c4_ur, data_s2_c4_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c1_ur, data_s3_c1_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c2_ur, data_s3_c2_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c3_ur, data_s3_c3_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s3_c4_ur, data_s3_c4_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c1_ur, data_s4_c1_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c2_ur, data_s4_c2_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c3_ur, data_s4_c3_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Plot2Datas(data_s4_c4_ur, data_s4_c4_ur_1D)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
