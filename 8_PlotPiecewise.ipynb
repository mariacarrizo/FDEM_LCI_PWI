# %%
# %matplotlib widget

# %% [markdown]
# # Plot results for upper conductive case

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, 'src')

from showStitched import showStitchedModels
from Plot import Plot2Datas, grid

# %%
# Load true models

# Slope 1 %
model_s1_c1_uc = np.load('models/model_s1_c1_uc.npy')
model_s1_c2_uc = np.load('models/model_s1_c2_uc.npy')
model_s1_c3_uc = np.load('models/model_s1_c3_uc.npy')
model_s1_c4_uc = np.load('models/model_s1_c4_uc.npy')

# Slope 2 %
model_s2_c1_uc = np.load('models/model_s2_c1_uc.npy')
model_s2_c2_uc = np.load('models/model_s2_c2_uc.npy')
model_s2_c3_uc = np.load('models/model_s2_c3_uc.npy')
model_s2_c4_uc = np.load('models/model_s2_c4_uc.npy')

# Slope 5 %
model_s3_c1_uc = np.load('models/model_s3_c1_uc.npy')
model_s3_c2_uc = np.load('models/model_s3_c2_uc.npy')
model_s3_c3_uc = np.load('models/model_s3_c3_uc.npy')
model_s3_c4_uc = np.load('models/model_s3_c4_uc.npy')

# Slope 10 %
model_s4_c1_uc = np.load('models/model_s4_c1_uc.npy')
model_s4_c2_uc = np.load('models/model_s4_c2_uc.npy')
model_s4_c3_uc = np.load('models/model_s4_c3_uc.npy')
model_s4_c4_uc = np.load('models/model_s4_c4_uc.npy')

# Load true data

# Slope 1 %
data_s1_c1_uc = np.load('data/data_s1_c1_uc_sort.npy')
data_s1_c2_uc = np.load('data/data_s1_c2_uc_sort.npy')
data_s1_c3_uc = np.load('data/data_s1_c3_uc_sort.npy')
data_s1_c4_uc = np.load('data/data_s1_c4_uc_sort.npy')

# Slope 2 %
data_s2_c1_uc = np.load('data/data_s2_c1_uc_sort.npy')
data_s2_c2_uc = np.load('data/data_s2_c2_uc_sort.npy')
data_s2_c3_uc = np.load('data/data_s2_c3_uc_sort.npy')
data_s2_c4_uc = np.load('data/data_s2_c4_uc_sort.npy')

# Slope 5 %
data_s3_c1_uc = np.load('data/data_s3_c1_uc_sort.npy')
data_s3_c2_uc = np.load('data/data_s3_c2_uc_sort.npy')
data_s3_c3_uc = np.load('data/data_s3_c3_uc_sort.npy')
data_s3_c4_uc = np.load('data/data_s3_c4_uc_sort.npy')

# Slope 10 %
data_s4_c1_uc = np.load('data/data_s4_c1_uc_sort.npy')
data_s4_c2_uc = np.load('data/data_s4_c2_uc_sort.npy')
data_s4_c3_uc = np.load('data/data_s4_c3_uc_sort.npy')
data_s4_c4_uc = np.load('data/data_s4_c4_uc_sort.npy')

# Load inverted models

# Slope 1 %
model_inv_s1_c1_uc = np.load('results/model_inv_s1_c1_uc1D.npy')
model_inv_s1_c2_uc = np.load('results/model_inv_s1_c2_uc1D.npy')
model_inv_s1_c3_uc = np.load('results/model_inv_s1_c3_uc1D.npy')
model_inv_s1_c4_uc = np.load('results/model_inv_s1_c4_uc1D.npy')

# Slope 2 %
model_inv_s2_c1_uc = np.load('results/model_inv_s2_c1_uc1D.npy')
model_inv_s2_c2_uc = np.load('results/model_inv_s2_c2_uc1D.npy')
model_inv_s2_c3_uc = np.load('results/model_inv_s2_c3_uc1D.npy')
model_inv_s2_c4_uc = np.load('results/model_inv_s2_c4_uc1D.npy')

# Slope 5 %
model_inv_s3_c1_uc = np.load('results/model_inv_s3_c1_uc1D.npy')
model_inv_s3_c2_uc = np.load('results/model_inv_s3_c2_uc1D.npy')
model_inv_s3_c3_uc = np.load('results/model_inv_s3_c3_uc1D.npy')
model_inv_s3_c4_uc = np.load('results/model_inv_s3_c4_uc1D.npy')

# Slope 10 %
model_inv_s4_c1_uc = np.load('results/model_inv_s4_c1_uc1D.npy')
model_inv_s4_c2_uc = np.load('results/model_inv_s4_c2_uc1D.npy')
model_inv_s4_c3_uc = np.load('results/model_inv_s4_c3_uc1D.npy')
model_inv_s4_c4_uc = np.load('results/model_inv_s4_c4_uc1D.npy')

# Load inverted model response

# Slope 1 %
data_inv_s1_c1_uc = np.load('results/data_inv_s1_c1_uc1D.npy')
data_inv_s1_c2_uc = np.load('results/data_inv_s1_c2_uc1D.npy')
data_inv_s1_c3_uc = np.load('results/data_inv_s1_c3_uc1D.npy')
data_inv_s1_c4_uc = np.load('results/data_inv_s1_c4_uc1D.npy')

# Slope 2 %
data_inv_s2_c1_uc = np.load('results/data_inv_s2_c1_uc1D.npy')
data_inv_s2_c2_uc = np.load('results/data_inv_s2_c2_uc1D.npy')
data_inv_s2_c3_uc = np.load('results/data_inv_s2_c3_uc1D.npy')
data_inv_s2_c4_uc = np.load('results/data_inv_s2_c4_uc1D.npy')

# Slope 5 %
data_inv_s3_c1_uc = np.load('results/data_inv_s3_c1_uc1D.npy')
data_inv_s3_c2_uc = np.load('results/data_inv_s3_c2_uc1D.npy')
data_inv_s3_c3_uc = np.load('results/data_inv_s3_c3_uc1D.npy')
data_inv_s3_c4_uc = np.load('results/data_inv_s3_c4_uc1D.npy')

# Slope 10 %
data_inv_s4_c1_uc = np.load('results/data_inv_s4_c1_uc1D.npy')
data_inv_s4_c2_uc = np.load('results/data_inv_s4_c2_uc1D.npy')
data_inv_s4_c3_uc = np.load('results/data_inv_s4_c3_uc1D.npy')
data_inv_s4_c4_uc = np.load('results/data_inv_s4_c4_uc1D.npy')

# %%
# Load true models

# Slope 1 %
model_s1_c1_ur = np.load('models/model_s1_c1_ur.npy')
model_s1_c2_ur = np.load('models/model_s1_c2_ur.npy')
model_s1_c3_ur = np.load('models/model_s1_c3_ur.npy')
model_s1_c4_ur = np.load('models/model_s1_c4_ur.npy')

# Slope 2 %
model_s2_c1_ur = np.load('models/model_s2_c1_ur.npy')
model_s2_c2_ur = np.load('models/model_s2_c2_ur.npy')
model_s2_c3_ur = np.load('models/model_s2_c3_ur.npy')
model_s2_c4_ur = np.load('models/model_s2_c4_ur.npy')

# Slope 5 %
model_s3_c1_ur = np.load('models/model_s3_c1_ur.npy')
model_s3_c2_ur = np.load('models/model_s3_c2_ur.npy')
model_s3_c3_ur = np.load('models/model_s3_c3_ur.npy')
model_s3_c4_ur = np.load('models/model_s3_c4_ur.npy')

# Slope 10 %
model_s4_c1_ur = np.load('models/model_s4_c1_ur.npy')
model_s4_c2_ur = np.load('models/model_s4_c2_ur.npy')
model_s4_c3_ur = np.load('models/model_s4_c3_ur.npy')
model_s4_c4_ur = np.load('models/model_s4_c4_ur.npy')

# Load true data

# Slope 1 %
data_s1_c1_ur = np.load('data/data_s1_c1_ur_sort.npy')
data_s1_c2_ur = np.load('data/data_s1_c2_ur_sort.npy')
data_s1_c3_ur = np.load('data/data_s1_c3_ur_sort.npy')
data_s1_c4_ur = np.load('data/data_s1_c4_ur_sort.npy')

# Slope 2 %
data_s2_c1_ur = np.load('data/data_s2_c1_ur_sort.npy')
data_s2_c2_ur = np.load('data/data_s2_c2_ur_sort.npy')
data_s2_c3_ur = np.load('data/data_s2_c3_ur_sort.npy')
data_s2_c4_ur = np.load('data/data_s2_c4_ur_sort.npy')

# Slope 5 %
data_s3_c1_ur = np.load('data/data_s3_c1_ur_sort.npy')
data_s3_c2_ur = np.load('data/data_s3_c2_ur_sort.npy')
data_s3_c3_ur = np.load('data/data_s3_c3_ur_sort.npy')
data_s3_c4_ur = np.load('data/data_s3_c4_ur_sort.npy')

# Slope 10 %
data_s4_c1_ur = np.load('data/data_s4_c1_ur_sort.npy')
data_s4_c2_ur = np.load('data/data_s4_c2_ur_sort.npy')
data_s4_c3_ur = np.load('data/data_s4_c3_ur_sort.npy')
data_s4_c4_ur = np.load('data/data_s4_c4_ur_sort.npy')

# Load inverted models

# Slope 1 %
model_inv_s1_c1_ur = np.load('results/model_inv_s1_c1_ur1D.npy')
model_inv_s1_c2_ur = np.load('results/model_inv_s1_c2_ur1D.npy')
model_inv_s1_c3_ur = np.load('results/model_inv_s1_c3_ur1D.npy')
model_inv_s1_c4_ur = np.load('results/model_inv_s1_c4_ur1D.npy')

# Slope 2 %
model_inv_s2_c1_ur = np.load('results/model_inv_s2_c1_ur1D.npy')
model_inv_s2_c2_ur = np.load('results/model_inv_s2_c2_ur1D.npy')
model_inv_s2_c3_ur = np.load('results/model_inv_s2_c3_ur1D.npy')
model_inv_s2_c4_ur = np.load('results/model_inv_s2_c4_ur1D.npy')

# Slope 5 %
model_inv_s3_c1_ur = np.load('results/model_inv_s3_c1_ur1D.npy')
model_inv_s3_c2_ur = np.load('results/model_inv_s3_c2_ur1D.npy')
model_inv_s3_c3_ur = np.load('results/model_inv_s3_c3_ur1D.npy')
model_inv_s3_c4_ur = np.load('results/model_inv_s3_c4_ur1D.npy')

# Slope 10 %
model_inv_s4_c1_ur = np.load('results/model_inv_s4_c1_ur1D.npy')
model_inv_s4_c2_ur = np.load('results/model_inv_s4_c2_ur1D.npy')
model_inv_s4_c3_ur = np.load('results/model_inv_s4_c3_ur1D.npy')
model_inv_s4_c4_ur = np.load('results/model_inv_s4_c4_ur1D.npy')

# Load inverted model response

# Slope 1 %
data_inv_s1_c1_ur = np.load('results/data_inv_s1_c1_ur1D.npy')
data_inv_s1_c2_ur = np.load('results/data_inv_s1_c2_ur1D.npy')
data_inv_s1_c3_ur = np.load('results/data_inv_s1_c3_ur1D.npy')
data_inv_s1_c4_ur = np.load('results/data_inv_s1_c4_ur1D.npy')

# Slope 2 %
data_inv_s2_c1_ur = np.load('results/data_inv_s2_c1_ur1D.npy')
data_inv_s2_c2_ur = np.load('results/data_inv_s2_c2_ur1D.npy')
data_inv_s2_c3_ur = np.load('results/data_inv_s2_c3_ur1D.npy')
data_inv_s2_c4_ur = np.load('results/data_inv_s2_c4_ur1D.npy')

# Slope 5 %
data_inv_s3_c1_ur = np.load('results/data_inv_s3_c1_ur1D.npy')
data_inv_s3_c2_ur = np.load('results/data_inv_s3_c2_ur1D.npy')
data_inv_s3_c3_ur = np.load('results/data_inv_s3_c3_ur1D.npy')
data_inv_s3_c4_ur = np.load('results/data_inv_s3_c4_ur1D.npy')

# Slope 10 %
data_inv_s4_c1_ur = np.load('results/data_inv_s4_c1_ur1D.npy')
data_inv_s4_c2_ur = np.load('results/data_inv_s4_c2_ur1D.npy')
data_inv_s4_c3_ur = np.load('results/data_inv_s4_c3_ur1D.npy')
data_inv_s4_c4_ur = np.load('results/data_inv_s4_c4_ur1D.npy')

# %%
# Calculate grids

m_s1_c1_uc_g = grid(model_s1_c1_uc, depthmax=6, nlay=2)
m_s1_c2_uc_g = grid(model_s1_c2_uc, depthmax=6, nlay=2)
m_s1_c3_uc_g = grid(model_s1_c3_uc, depthmax=6, nlay=2)
m_s1_c4_uc_g = grid(model_s1_c4_uc, depthmax=6, nlay=2)

m_s2_c1_uc_g = grid(model_s2_c1_uc, depthmax=6, nlay=2)
m_s2_c2_uc_g = grid(model_s2_c2_uc, depthmax=6, nlay=2)
m_s2_c3_uc_g = grid(model_s2_c3_uc, depthmax=6, nlay=2)
m_s2_c4_uc_g = grid(model_s2_c4_uc, depthmax=6, nlay=2)

m_s3_c1_uc_g = grid(model_s3_c1_uc, depthmax=6, nlay=2)
m_s3_c2_uc_g = grid(model_s3_c2_uc, depthmax=6, nlay=2)
m_s3_c3_uc_g = grid(model_s3_c3_uc, depthmax=6, nlay=2)
m_s3_c4_uc_g = grid(model_s3_c4_uc, depthmax=6, nlay=2)

m_s4_c1_uc_g = grid(model_s4_c1_uc, depthmax=6, nlay=2)
m_s4_c2_uc_g = grid(model_s4_c2_uc, depthmax=6, nlay=2)
m_s4_c3_uc_g = grid(model_s4_c3_uc, depthmax=6, nlay=2)
m_s4_c4_uc_g = grid(model_s4_c4_uc, depthmax=6, nlay=2)

mi_s1_c1_uc_g = grid(model_inv_s1_c1_uc, depthmax=6, nlay=2)
mi_s1_c2_uc_g = grid(model_inv_s1_c2_uc, depthmax=6, nlay=2)
mi_s1_c3_uc_g = grid(model_inv_s1_c3_uc, depthmax=6, nlay=2)
mi_s1_c4_uc_g = grid(model_inv_s1_c4_uc, depthmax=6, nlay=2)

mi_s1_c1_ur_g = grid(model_inv_s1_c1_ur, depthmax=6, nlay=2)
mi_s1_c2_ur_g = grid(model_inv_s1_c2_ur, depthmax=6, nlay=2)
mi_s1_c3_ur_g = grid(model_inv_s1_c3_ur, depthmax=6, nlay=2)
mi_s1_c4_ur_g = grid(model_inv_s1_c4_ur, depthmax=6, nlay=2)

mi_s2_c1_uc_g = grid(model_inv_s2_c1_uc, depthmax=6, nlay=2)
mi_s2_c2_uc_g = grid(model_inv_s2_c2_uc, depthmax=6, nlay=2)
mi_s2_c3_uc_g = grid(model_inv_s2_c3_uc, depthmax=6, nlay=2)
mi_s2_c4_uc_g = grid(model_inv_s2_c4_uc, depthmax=6, nlay=2)

mi_s3_c1_uc_g = grid(model_inv_s3_c1_uc, depthmax=6, nlay=2)
mi_s3_c2_uc_g = grid(model_inv_s3_c2_uc, depthmax=6, nlay=2)
mi_s3_c3_uc_g = grid(model_inv_s3_c3_uc, depthmax=6, nlay=2)
mi_s3_c4_uc_g = grid(model_inv_s3_c4_uc, depthmax=6, nlay=2)

mi_s4_c1_uc_g = grid(model_inv_s4_c1_uc, depthmax=6, nlay=2)
mi_s4_c2_uc_g = grid(model_inv_s4_c2_uc, depthmax=6, nlay=2)
mi_s4_c3_uc_g = grid(model_inv_s4_c3_uc, depthmax=6, nlay=2)
mi_s4_c4_uc_g = grid(model_inv_s4_c4_uc, depthmax=6, nlay=2)

# %%
# Calculate grids

m_s1_c1_ur_g = grid(model_s1_c1_ur, depthmax=6, nlay=2)
m_s1_c2_ur_g = grid(model_s1_c2_ur, depthmax=6, nlay=2)
m_s1_c3_ur_g = grid(model_s1_c3_ur, depthmax=6, nlay=2)
m_s1_c4_ur_g = grid(model_s1_c4_ur, depthmax=6, nlay=2)

m_s2_c1_ur_g = grid(model_s2_c1_ur, depthmax=6, nlay=2)
m_s2_c2_ur_g = grid(model_s2_c2_ur, depthmax=6, nlay=2)
m_s2_c3_ur_g = grid(model_s2_c3_ur, depthmax=6, nlay=2)
m_s2_c4_ur_g = grid(model_s2_c4_ur, depthmax=6, nlay=2)

m_s3_c1_ur_g = grid(model_s3_c1_ur, depthmax=6, nlay=2)
m_s3_c2_ur_g = grid(model_s3_c2_ur, depthmax=6, nlay=2)
m_s3_c3_ur_g = grid(model_s3_c3_ur, depthmax=6, nlay=2)
m_s3_c4_ur_g = grid(model_s3_c4_ur, depthmax=6, nlay=2)

m_s4_c1_ur_g = grid(model_s4_c1_ur, depthmax=6, nlay=2)
m_s4_c2_ur_g = grid(model_s4_c2_ur, depthmax=6, nlay=2)
m_s4_c3_ur_g = grid(model_s4_c3_ur, depthmax=6, nlay=2)
m_s4_c4_ur_g = grid(model_s4_c4_ur, depthmax=6, nlay=2)

mi_s1_c1_ur_g = grid(model_inv_s1_c1_ur, depthmax=6, nlay=2)
mi_s1_c2_ur_g = grid(model_inv_s1_c2_ur, depthmax=6, nlay=2)
mi_s1_c3_ur_g = grid(model_inv_s1_c3_ur, depthmax=6, nlay=2)
mi_s1_c4_ur_g = grid(model_inv_s1_c4_ur, depthmax=6, nlay=2)

mi_s2_c1_ur_g = grid(model_inv_s2_c1_ur, depthmax=6, nlay=2)
mi_s2_c2_ur_g = grid(model_inv_s2_c2_ur, depthmax=6, nlay=2)
mi_s2_c3_ur_g = grid(model_inv_s2_c3_ur, depthmax=6, nlay=2)
mi_s2_c4_ur_g = grid(model_inv_s2_c4_ur, depthmax=6, nlay=2)

mi_s3_c1_ur_g = grid(model_inv_s3_c1_ur, depthmax=6, nlay=2)
mi_s3_c2_ur_g = grid(model_inv_s3_c2_ur, depthmax=6, nlay=2)
mi_s3_c3_ur_g = grid(model_inv_s3_c3_ur, depthmax=6, nlay=2)
mi_s3_c4_ur_g = grid(model_inv_s3_c4_ur, depthmax=6, nlay=2)

mi_s4_c1_ur_g = grid(model_inv_s4_c1_ur, depthmax=6, nlay=2)
mi_s4_c2_ur_g = grid(model_inv_s4_c2_ur, depthmax=6, nlay=2)
mi_s4_c3_ur_g = grid(model_inv_s4_c3_ur, depthmax=6, nlay=2)
mi_s4_c4_ur_g = grid(model_inv_s4_c4_ur, depthmax=6, nlay=2)

# %%
# Calculate relative error

rel_diff_s1_c1_uc = (np.abs((m_s1_c1_uc_g-mi_s1_c1_uc_g)/m_s1_c1_uc_g))*100
rel_diff_s1_c2_uc = (np.abs((m_s1_c2_uc_g-mi_s1_c2_uc_g)/m_s1_c2_uc_g))*100
rel_diff_s1_c3_uc = (np.abs((m_s1_c3_uc_g-mi_s1_c3_uc_g)/m_s1_c3_uc_g))*100
rel_diff_s1_c4_uc = (np.abs((m_s1_c4_uc_g-mi_s1_c4_uc_g)/m_s1_c4_uc_g))*100

rel_diff_s2_c1_uc = (np.abs((m_s2_c1_uc_g-mi_s2_c1_uc_g)/m_s2_c1_uc_g))*100
rel_diff_s2_c2_uc = (np.abs((m_s2_c2_uc_g-mi_s2_c2_uc_g)/m_s2_c2_uc_g))*100
rel_diff_s2_c3_uc = (np.abs((m_s2_c3_uc_g-mi_s2_c3_uc_g)/m_s2_c3_uc_g))*100
rel_diff_s2_c4_uc = (np.abs((m_s2_c4_uc_g-mi_s2_c4_uc_g)/m_s2_c4_uc_g))*100

rel_diff_s3_c1_uc = (np.abs((m_s3_c1_uc_g-mi_s3_c1_uc_g)/m_s3_c1_uc_g))*100
rel_diff_s3_c2_uc = (np.abs((m_s3_c2_uc_g-mi_s3_c2_uc_g)/m_s3_c2_uc_g))*100
rel_diff_s3_c3_uc = (np.abs((m_s3_c3_uc_g-mi_s3_c3_uc_g)/m_s3_c3_uc_g))*100
rel_diff_s3_c4_uc = (np.abs((m_s3_c4_uc_g-mi_s3_c4_uc_g)/m_s3_c4_uc_g))*100

rel_diff_s4_c1_uc = (np.abs((m_s4_c1_uc_g-mi_s4_c1_uc_g)/m_s4_c1_uc_g))*100
rel_diff_s4_c2_uc = (np.abs((m_s4_c2_uc_g-mi_s4_c2_uc_g)/m_s4_c2_uc_g))*100
rel_diff_s4_c3_uc = (np.abs((m_s4_c3_uc_g-mi_s4_c3_uc_g)/m_s4_c3_uc_g))*100
rel_diff_s4_c4_uc = (np.abs((m_s4_c4_uc_g-mi_s4_c4_uc_g)/m_s4_c4_uc_g))*100

# %%
# Calculate relative error

rel_diff_s1_c1_ur = (np.abs((m_s1_c1_ur_g-mi_s1_c1_ur_g)/m_s1_c1_ur_g))*100
rel_diff_s1_c2_ur = (np.abs((m_s1_c2_ur_g-mi_s1_c2_ur_g)/m_s1_c2_ur_g))*100
rel_diff_s1_c3_ur = (np.abs((m_s1_c3_ur_g-mi_s1_c3_ur_g)/m_s1_c3_ur_g))*100
rel_diff_s1_c4_ur = (np.abs((m_s1_c4_ur_g-mi_s1_c4_ur_g)/m_s1_c4_ur_g))*100

rel_diff_s2_c1_ur = (np.abs((m_s2_c1_ur_g-mi_s2_c1_ur_g)/m_s2_c1_ur_g))*100
rel_diff_s2_c2_ur = (np.abs((m_s2_c2_ur_g-mi_s2_c2_ur_g)/m_s2_c2_ur_g))*100
rel_diff_s2_c3_ur = (np.abs((m_s2_c3_ur_g-mi_s2_c3_ur_g)/m_s2_c3_ur_g))*100
rel_diff_s2_c4_ur = (np.abs((m_s2_c4_ur_g-mi_s2_c4_ur_g)/m_s2_c4_ur_g))*100

rel_diff_s3_c1_ur = (np.abs((m_s3_c1_ur_g-mi_s3_c1_ur_g)/m_s3_c1_ur_g))*100
rel_diff_s3_c2_ur = (np.abs((m_s3_c2_ur_g-mi_s3_c2_ur_g)/m_s3_c2_ur_g))*100
rel_diff_s3_c3_ur = (np.abs((m_s3_c3_ur_g-mi_s3_c3_ur_g)/m_s3_c3_ur_g))*100
rel_diff_s3_c4_ur = (np.abs((m_s3_c4_ur_g-mi_s3_c4_ur_g)/m_s3_c4_ur_g))*100

rel_diff_s4_c1_ur = (np.abs((m_s4_c1_ur_g-mi_s4_c1_ur_g)/m_s4_c1_ur_g))*100
rel_diff_s4_c2_ur = (np.abs((m_s4_c2_ur_g-mi_s4_c2_ur_g)/m_s4_c2_ur_g))*100
rel_diff_s4_c3_ur = (np.abs((m_s4_c3_ur_g-mi_s4_c3_ur_g)/m_s4_c3_ur_g))*100
rel_diff_s4_c4_ur = (np.abs((m_s4_c4_ur_g-mi_s4_c4_ur_g)/m_s4_c4_ur_g))*100

# %%
def PlotModels(mt_c1, mt_c2, mt_c3, mt_c4, mi_c1, mi_c2, mi_c3, mi_c4, rd_c1, rd_c2, rd_c3, rd_c4, slope=''):
    fig, ax = plt.subplots(4,3, sharex=True, sharey=True, figsize=(10,6))

    inputs = {'cMin':10/1000,
              'cMax':1800/1000,
              'colorBar' : True,
              'orientation' : 'vertical',
               # 'label': '$\sigma$ [mS/m]',
              'fontsize':7, 
              'labelsize':7
              }

    zMax=6
    fs = 7

    # c1
    showStitchedModels(mt_c1, ax=ax[0,0], **inputs, zMax=zMax)
    ax[0,0].set_title('True model - Slope '+slope+'%', fontsize=fs)

    showStitchedModels(mi_c1, ax=ax[0,1], **inputs, zMax=zMax)
    ax[0,1].set_title('Inverted model - Slope '+slope+'%', fontsize=fs)

    c = ax[0,2].imshow(rd_c1.T, extent=[0,40,-6,0], aspect=3.6, cmap='binary')
    ax[0,2].set_title('% (Rel diff)', fontsize=fs)
    #cb = fig.colorbar(c, ax=ax[0,2])

    # c2
    showStitchedModels(mt_c2, ax=ax[1,0], **inputs, zMax=zMax)
    ax[1,0].set_title('True model - Slope '+slope+'%', fontsize=fs)

    showStitchedModels(mi_c2, ax=ax[1,1], **inputs, zMax=zMax)
    ax[1,1].set_title('Inverted model - Slope '+slope+'%', fontsize=fs)

    c = ax[1,2].imshow(rd_c2.T, extent=[0,40,-6,0], aspect=3.6, cmap='binary')
    ax[1,2].set_title('% (Rel diff)', fontsize=fs)
    #cb = fig.colorbar(c, ax=ax[1,2])

    # c3
    showStitchedModels(mt_c3, ax=ax[2,0], **inputs, zMax=zMax)
    ax[2,0].set_title('True model - Slope '+slope+'%', fontsize=fs)

    showStitchedModels(mi_c3, ax=ax[2,1], **inputs, zMax=zMax)
    ax[2,1].set_title('Inverted model - Slope '+slope+'%', fontsize=fs)

    c = ax[2,2].imshow(rd_c3.T, extent=[0,40,-6,0], aspect=3.6, cmap='binary')
    ax[2,2].set_title('% (Rel diff)', fontsize=fs)
    #cb = fig.colorbar(c, ax=ax[2,2])

    # c4
    showStitchedModels(mt_c4, ax=ax[3,0], **inputs, zMax=zMax)
    ax[3,0].set_title('True model - Slope '+slope+'%', fontsize=fs)

    showStitchedModels(mi_c4, ax=ax[3,1], **inputs, zMax=zMax)
    ax[3,1].set_title('Inverted model - Slope '+slope+'%', fontsize=fs)

    c = ax[3,2].imshow(rd_c4.T, extent=[0,40,-6,0], aspect=3.6, cmap='binary')
    ax[3,2].set_title('% (Rel diff)', fontsize=fs)
    #cb = fig.colorbar(c, ax=ax[3,2])


    plt.tight_layout()

# %%
PlotModels(model_s1_c1_uc, model_s1_c2_uc, model_s1_c3_uc, model_s1_c4_uc,
           model_inv_s1_c1_uc, model_inv_s1_c2_uc, model_inv_s1_c3_uc, model_inv_s1_c4_uc,
           rel_diff_s1_c1_uc, rel_diff_s1_c2_uc, rel_diff_s1_c3_uc, rel_diff_s1_c4_uc, slope='1')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s1_c1_uc, model_s1_c2_uc, model_s1_c3_uc, model_s1_c4_uc,
           model_inv_s1_c1_uc, model_inv_s1_c2_uc, model_inv_s1_c3_uc, model_inv_s1_c4_uc,
           rel_diff_s1_c1_uc, rel_diff_s1_c2_uc, rel_diff_s1_c3_uc, rel_diff_s1_c4_uc, slope='1')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s2_c1_uc, model_s2_c2_uc, model_s2_c3_uc, model_s2_c4_uc,
           model_inv_s2_c1_uc, model_inv_s2_c2_uc, model_inv_s2_c3_uc, model_inv_s2_c4_uc,
           rel_diff_s2_c1_uc, rel_diff_s2_c2_uc, rel_diff_s2_c3_uc, rel_diff_s2_c4_uc, slope='2')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s3_c1_uc, model_s3_c2_uc, model_s3_c3_uc, model_s3_c4_uc,
           model_inv_s3_c1_uc, model_inv_s3_c2_uc, model_inv_s3_c3_uc, model_inv_s3_c4_uc,
           rel_diff_s3_c1_uc, rel_diff_s3_c2_uc, rel_diff_s3_c3_uc, rel_diff_s3_c4_uc, slope='5')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s4_c1_uc, model_s4_c2_uc, model_s4_c3_uc, model_s4_c4_uc,
           model_inv_s4_c1_uc, model_inv_s4_c2_uc, model_inv_s4_c3_uc, model_inv_s4_c4_uc,
           rel_diff_s4_c1_uc, rel_diff_s4_c2_uc, rel_diff_s4_c3_uc, rel_diff_s4_c4_uc, slope='10')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Upper resistive

# %%
PlotModels(model_s1_c1_ur, model_s1_c2_ur, model_s1_c3_ur, model_s1_c4_ur,
           model_inv_s1_c1_ur, model_inv_s1_c2_ur, model_inv_s1_c3_ur, model_inv_s1_c4_ur,
           rel_diff_s1_c1_ur, rel_diff_s1_c2_ur, rel_diff_s1_c3_ur, rel_diff_s1_c4_ur, slope='1')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s2_c1_ur, model_s2_c2_ur, model_s2_c3_ur, model_s2_c4_ur,
           model_inv_s2_c1_ur, model_inv_s2_c2_ur, model_inv_s2_c3_ur, model_inv_s2_c4_ur,
           rel_diff_s2_c1_ur, rel_diff_s2_c2_ur, rel_diff_s2_c3_ur, rel_diff_s2_c4_ur, slope='2')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s3_c1_ur, model_s3_c2_ur, model_s3_c3_ur, model_s3_c4_ur,
           model_inv_s3_c1_ur, model_inv_s3_c2_ur, model_inv_s3_c3_ur, model_inv_s3_c4_ur,
           rel_diff_s3_c1_ur, rel_diff_s3_c2_ur, rel_diff_s3_c3_ur, rel_diff_s3_c4_ur, slope='5')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
PlotModels(model_s4_c1_ur, model_s4_c2_ur, model_s4_c3_ur, model_s4_c4_ur,
           model_inv_s4_c1_ur, model_inv_s4_c2_ur, model_inv_s4_c3_ur, model_inv_s4_c4_ur,
           rel_diff_s4_c1_ur, rel_diff_s4_c2_ur, rel_diff_s4_c3_ur, rel_diff_s4_c4_ur, slope='10')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
